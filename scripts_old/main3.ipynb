# %% [markdown]
# # Bayesian sampling of ensembles

# %%
import os
import numpy as np
import jax
import jax.numpy as jnp
import matplotlib.pyplot as plt
import pandas

# %%
# import sys
# sys.path.append('../../3_alphabetagamma/')

# %%
# from MDRefine.MDRefine import load_data, normalize_observables, minimizer, unwrap_2dict
# from MDRefine.MDRefine import compute_chi2, compute_D_KL

# %%
from basic_functions import run_Metropolis, block_analysis

# %%
def energy_fun(new_weights, original_weights, if_Jeffreys, upto: int = 4):
    """ acting on single molecular system """

    # sys_names = data.properties.system_names
    # assert len(sys_names) == 1, 'this script works only for 1 molecular system'
    # sys_name = sys_names[0]

    # chi2 = compute_chi2(data.mol[sys_name].ref, new_weights, data.mol[sys_name].g, data.mol[sys_name].gexp)[3]
    dkl = np.sum(new_weights*np.log(new_weights/original_weights))

    # energy = 1/2*chi2 + alpha*dkl
    energy = dkl

    # quantity: population in the first frame/cluster over 4 total clusters
    quantity = np.sum(new_weights[:(len(new_weights)//upto)])
    
    # av_g = unwrap_2dict(out.av_g)[0] 

    if if_Jeffreys:
        # Jef_prior = 1/np.sqrt(np.prod(weights))
        # energy = -np.log(Jef_prior)

        # more efficient?
        energy += 1/2*np.sum(np.log(new_weights))
    
    return energy, quantity

# %%
def proposal(weights, dx = 0.01):
    """ Based on the stick-breaking process """

    if not np.sum(weights) == 1: weights = weights/np.sum(weights)

    x = np.cumsum(weights)[:-1]
    
    x += dx*np.random.normal(size=len(x))
    x = np.mod(x, 1)
    x = np.concatenate((np.sort(x), [1]))

    weights_new = np.concatenate(([x[0]], np.ediff1d(x)))

    return weights_new

# %%
def double(weights, n: int = 2):
    """ double if n = 2, else three times and so on """

    weights_double = np.zeros(len(weights)*n)

    for i in range(len(weights)):
        for j in range(n):
            weights_double[n*i + j] = weights[i]

    return weights_double

# %% [markdown]
# ### Toy model

# %% [markdown]
# #### invariance

# %% [markdown]
# $ds^2 = \sum_i \frac{dw_i^2}{w_{0i}}$
#
# is it invariant under coarse-graining? yes if the coarse-graining moves in the opposite direction by splitting frames into new frames with equal weights

# %%
w = np.array([1/8, 1/8, 1/4, 1/4, 1/8, 1/8])

w0 = np.array([1/4, 1/4, 1/8, 1/8, 1/8, 1/8])

compute_dist = lambda w, w0: np.sum((w-w0)**2)  # /w0)

d1 = compute_dist(w, w0)
print(d1)

# coarse-graining

new_w = []
new_w0 = []

for i in range(len(w)//2):
    new_w.append(w[2*i] + w[2*i + 1])
    new_w0.append(w0[2*i] + w0[2*i + 1])

new_w = np.array(new_w)
new_w0 = np.array(new_w0)

d1 = compute_dist(new_w, new_w0)
print(d1)
# Out:
# 0.0625
# 0.125

# %% [markdown]
# #### Metropolis

# %%
proposal_full = {'fun': proposal, 'args': ([0.001])}

# %%
weights = np.random.uniform(0, 1, size=50)
weights = weights/np.sum(weights)
original_weights = +weights

plt.plot(weights, '*-')

# %%
for i in range(5):

    new_weights = proposal(weights, dx=0.01)
    weights = new_weights

    plt.plot(new_weights, '.-')

plt.grid()

# %%
energy_fun_full = {'fun': energy_fun, 'args': ([original_weights, True])}

out = run_Metropolis(weights, proposal=proposal_full, energy_function=energy_fun_full, n_steps=10000)
# Out:
# Warning: the quantities of interest are given by energy_function and not by quantity_function
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900

# %%
plt.plot(out[1])

plt.figure()
plt.plot(out[2])



print(out[3])
# Out:
# 0.994

# %%
plt.plot(out[2])

print(out[3])
# Out:
# 0.1202

# %%
# observable: average weight of the first frame over 20

# %%
# plot of the sampled weights
plt.plot(out[0].T, '.')
plt.grid()
plt.show()

# %%
plt.plot(out[0])
# plt.plot(out[0][:, 1])
plt.grid()
plt.show()

print('av. acceptance: ', out[-1])
# Out:
# av. acceptance:  0.0473

# %%
plt.plot(out[2])

print(np.mean(out[2]))

blocks = block_analysis(out[2], delta=10)

epsilon = blocks[2]

plt.figure()
plt.plot(epsilon, '.-')
plt.xscale('log')
# Out:
# 0.27831071765278387

# %%
vec = np.random.normal(size=100000)

res = block_analysis(vec, delta=100)

# %%
plt.plot(res[2])
plt.xscale('log')

# %% [markdown]
# #### now, inverse coarse-graining
#
# double the frames

# %%
original_weights
# Out:
# array([0.06244842, 0.00641204, 0.05268427, 0.08010327, 0.0142057 ,
#        0.08690408, 0.06127748, 0.04505012, 0.02177928, 0.03645557,
#        0.02692952, 0.09029065, 0.00537328, 0.07270005, 0.03259012,
#        0.07715879, 0.08648534, 0.04884211, 0.06645245, 0.02585746])

# %%
original_weights_double = double(original_weights)

# %%
proposal_full = {'fun': proposal, 'args': ([0.0001])}
energy_fun_full = {'fun': energy_fun, 'args': ([original_weights_double, False])}

out = run_Metropolis(original_weights_double, proposal=proposal_full, energy_function=energy_fun_full, n_steps=10000)
# Out:
# Warning: the quantities of interest are given by energy_function and not by quantity_function
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900

# %%
plt.plot(out[1])

plt.figure()
plt.plot(out[2])

print(np.mean(out[2]))

blocks = block_analysis(out[2], delta=10)

epsilon = blocks[2]

plt.figure()
plt.plot(epsilon, '.-')
plt.xscale('log')
# Out:
# 0.28201960630475026

# %%
for i in range(12):
    plt.plot(out[0][:, i])


# plt.yscale('log')

# %%
print('av. acceptance: ', out[3])

plt.plot(out[1])

plt.figure()
plt.plot(out[2])

print(np.mean(out[2]))

blocks = block_analysis(out[2], delta=10)

epsilon = blocks[2]

plt.figure()
plt.plot(epsilon, '.-')
plt.xscale('log')
# Out:
# av. acceptance:  0.5409
# 0.23302306925303404

# %%
original_weights_double2 = double(original_weights_double)

# %% [markdown]
# ### Toy model - wrap up

# %%
size = 4

# %%
weights_orig = np.random.uniform(0, 1, size=size)
weights_orig = weights_orig/np.sum(weights_orig)

plt.bar(range(len(weights_orig)), weights_orig)
# Out:
# <BarContainer object of 4 artists>

# %%
delta_w = 1e-2
if_Jeffreys = True
n_steps = np.int(1e5)

proposal_full = {'fun': proposal, 'args': ([delta_w])}
energy_fun_full = {'fun': energy_fun, 'args': ([weights_orig, if_Jeffreys, size])}

out = run_Metropolis(weights_orig, proposal=proposal_full, energy_function=energy_fun_full, n_steps=n_steps)
# Out:
# Warning: the quantities of interest are given by energy_function and not by quantity_function
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900
# 10000
# 10100
# 10200
# 10300
# 10400
# 10500
# 10600
# 10700
# 10800
# 10900
# 11000
# 11100
# 11200
# 11300
# 11400
# 11500
# 11600
# 11700
# 11800
# 11900
# 12000
# 12100
# 12200
# 12300
# 12400
# 12500
# 12600
# 12700
# 12800
# 12900
# 13000
# 13100
# 13200
# 13300
# 13400
# 13500
# 13600
# 13700
# 13800
# 13900
# 14000
# 14100
# 14200
# 14300
# 14400
# 14500
# 14600
# 14700
# 14800
# 14900
# 15000
# 15100
# 15200
# 15300
# 15400
# 15500
# 15600
# 15700
# 15800
# 15900
# 16000
# 16100
# 16200
# 16300
# 16400
# 16500
# 16600
# 16700
# 16800
# 16900
# 17000
# 17100
# 17200
# 17300
# 17400
# 17500
# 17600
# 17700
# 17800
# 17900
# 18000
# 18100
# 18200
# 18300
# 18400
# 18500
# 18600
# 18700
# 18800
# 18900
# 19000
# 19100
# 19200
# 19300
# 19400
# 19500
# 19600
# 19700
# 19800
# 19900
# 20000
# 20100
# 20200
# 20300
# 20400
# 20500
# 20600
# 20700
# 20800
# 20900
# 21000
# 21100
# 21200
# 21300
# 21400
# 21500
# 21600
# 21700
# 21800
# 21900
# 22000
# 22100
# 22200
# 22300
# 22400
# 22500
# 22600
# 22700
# 22800
# 22900
# 23000
# 23100
# 23200
# 23300
# 23400
# 23500
# 23600
# 23700
# 23800
# 23900
# 24000
# 24100
# 24200
# 24300
# 24400
# 24500
# 24600
# 24700
# 24800
# 24900
# 25000
# 25100
# 25200
# 25300
# 25400
# 25500
# 25600
# 25700
# 25800
# 25900
# 26000
# 26100
# 26200
# 26300
# 26400
# 26500
# 26600
# 26700
# 26800
# 26900
# 27000
# 27100
# 27200
# 27300
# 27400
# 27500
# 27600
# 27700
# 27800
# 27900
# 28000
# 28100
# 28200
# 28300
# 28400
# 28500
# 28600
# 28700
# 28800
# 28900
# 29000
# 29100
# 29200
# 29300
# 29400
# 29500
# 29600
# 29700
# 29800
# 29900
# 30000
# 30100
# 30200
# 30300
# 30400
# 30500
# 30600
# 30700
# 30800
# 30900
# 31000
# 31100
# 31200
# 31300
# 31400
# 31500
# 31600
# 31700
# 31800
# 31900
# 32000
# 32100
# 32200
# 32300
# 32400
# 32500
# 32600
# 32700
# 32800
# 32900
# 33000
# 33100
# 33200
# 33300
# 33400
# 33500
# 33600
# 33700
# 33800
# 33900
# 34000
# 34100
# 34200
# 34300
# 34400
# 34500
# 34600
# 34700
# 34800
# 34900
# 35000
# 35100
# 35200
# 35300
# 35400
# 35500
# 35600
# 35700
# 35800
# 35900
# 36000
# 36100
# 36200
# 36300
# 36400
# 36500
# 36600
# 36700
# 36800
# 36900
# 37000
# 37100
# 37200
# 37300
# 37400
# 37500
# 37600
# 37700
# 37800
# 37900
# 38000
# 38100
# 38200
# 38300
# 38400
# 38500
# 38600
# 38700
# 38800
# 38900
# 39000
# 39100
# 39200
# 39300
# 39400
# 39500
# 39600
# 39700
# 39800
# 39900
# 40000
# 40100
# 40200
# 40300
# 40400
# 40500
# 40600
# 40700
# 40800
# 40900
# 41000
# 41100
# 41200
# 41300
# 41400
# 41500
# 41600
# 41700
# 41800
# 41900
# 42000
# 42100
# 42200
# 42300
# 42400
# 42500
# 42600
# 42700
# 42800
# 42900
# 43000
# 43100
# 43200
# 43300
# 43400
# 43500
# 43600
# 43700
# 43800
# 43900
# 44000
# 44100
# 44200
# 44300
# 44400
# 44500
# 44600
# 44700
# 44800
# 44900
# 45000
# 45100
# 45200
# 45300
# 45400
# 45500
# 45600
# 45700
# 45800
# 45900
# 46000
# 46100
# 46200
# 46300
# 46400
# 46500
# 46600
# 46700
# 46800
# 46900
# 47000
# 47100
# 47200
# 47300
# 47400
# 47500
# 47600
# 47700
# 47800
# 47900
# 48000
# 48100
# 48200
# 48300
# 48400
# 48500
# 48600
# 48700
# 48800
# 48900
# 49000
# 49100
# 49200
# 49300
# 49400
# 49500
# 49600
# 49700
# 49800
# 49900
# 50000
# 50100
# 50200
# 50300
# 50400
# 50500
# 50600
# 50700
# 50800
# 50900
# 51000
# 51100
# 51200
# 51300
# 51400
# 51500
# 51600
# 51700
# 51800
# 51900
# 52000
# 52100
# 52200
# 52300
# 52400
# 52500
# 52600
# 52700
# 52800
# 52900
# 53000
# 53100
# 53200
# 53300
# 53400
# 53500
# 53600
# 53700
# 53800
# 53900
# 54000
# 54100
# 54200
# 54300
# 54400
# 54500
# 54600
# 54700
# 54800
# 54900
# 55000
# 55100
# 55200
# 55300
# 55400
# 55500
# 55600
# 55700
# 55800
# 55900
# 56000
# 56100
# 56200
# 56300
# 56400
# 56500
# 56600
# 56700
# 56800
# 56900
# 57000
# 57100
# 57200
# 57300
# 57400
# 57500
# 57600
# 57700
# 57800
# 57900
# 58000
# 58100
# 58200
# 58300
# 58400
# 58500
# 58600
# 58700
# 58800
# 58900
# 59000
# 59100
# 59200
# 59300
# 59400
# 59500
# 59600
# 59700
# 59800
# 59900
# 60000
# 60100
# 60200
# 60300
# 60400
# 60500
# 60600
# 60700
# 60800
# 60900
# 61000
# 61100
# 61200
# 61300
# 61400
# 61500
# 61600
# 61700
# 61800
# 61900
# 62000
# 62100
# 62200
# 62300
# 62400
# 62500
# 62600
# 62700
# 62800
# 62900
# 63000
# 63100
# 63200
# 63300
# 63400
# 63500
# 63600
# 63700
# 63800
# 63900
# 64000
# 64100
# 64200
# 64300
# 64400
# 64500
# 64600
# 64700
# 64800
# 64900
# 65000
# 65100
# 65200
# 65300
# 65400
# 65500
# 65600
# 65700
# 65800
# 65900
# 66000
# 66100
# 66200
# 66300
# 66400
# 66500
# 66600
# 66700
# 66800
# 66900
# 67000
# 67100
# 67200
# 67300
# 67400
# 67500
# 67600
# 67700
# 67800
# 67900
# 68000
# 68100
# 68200
# 68300
# 68400
# 68500
# 68600
# 68700
# 68800
# 68900
# 69000
# 69100
# 69200
# 69300
# 69400
# 69500
# 69600
# 69700
# 69800
# 69900
# 70000
# 70100
# 70200
# 70300
# 70400
# 70500
# 70600
# 70700
# 70800
# 70900
# 71000
# 71100
# 71200
# 71300
# 71400
# 71500
# 71600
# 71700
# 71800
# 71900
# 72000
# 72100
# 72200
# 72300
# 72400
# 72500
# 72600
# 72700
# 72800
# 72900
# 73000
# 73100
# 73200
# 73300
# 73400
# 73500
# 73600
# 73700
# 73800
# 73900
# 74000
# 74100
# 74200
# 74300
# 74400
# 74500
# 74600
# 74700
# 74800
# 74900
# 75000
# 75100
# 75200
# 75300
# 75400
# 75500
# 75600
# 75700
# 75800
# 75900
# 76000
# 76100
# 76200
# 76300
# 76400
# 76500
# 76600
# 76700
# 76800
# 76900
# 77000
# 77100
# 77200
# 77300
# 77400
# 77500
# 77600
# 77700
# 77800
# 77900
# 78000
# 78100
# 78200
# 78300
# 78400
# 78500
# 78600
# 78700
# 78800
# 78900
# 79000
# 79100
# 79200
# 79300
# 79400
# 79500
# 79600
# 79700
# 79800
# 79900
# 80000
# 80100
# 80200
# 80300
# 80400
# 80500
# 80600
# 80700
# 80800
# 80900
# 81000
# 81100
# 81200
# 81300
# 81400
# 81500
# 81600
# 81700
# 81800
# 81900
# 82000
# 82100
# 82200
# 82300
# 82400
# 82500
# 82600
# 82700
# 82800
# 82900
# 83000
# 83100
# 83200
# 83300
# 83400
# 83500
# 83600
# 83700
# 83800
# 83900
# 84000
# 84100
# 84200
# 84300
# 84400
# 84500
# 84600
# 84700
# 84800
# 84900
# 85000
# 85100
# 85200
# 85300
# 85400
# 85500
# 85600
# 85700
# 85800
# 85900
# 86000
# 86100
# 86200
# 86300
# 86400
# 86500
# 86600
# 86700
# 86800
# 86900
# 87000
# 87100
# 87200
# 87300
# 87400
# 87500
# 87600
# 87700
# 87800
# 87900
# 88000
# 88100
# 88200
# 88300
# 88400
# 88500
# 88600
# 88700
# 88800
# 88900
# 89000
# 89100
# 89200
# 89300
# 89400
# 89500
# 89600
# 89700
# 89800
# 89900
# 90000
# 90100
# 90200
# 90300
# 90400
# 90500
# 90600
# 90700
# 90800
# 90900
# 91000
# 91100
# 91200
# 91300
# 91400
# 91500
# 91600
# 91700
# 91800
# 91900
# 92000
# 92100
# 92200
# 92300
# 92400
# 92500
# 92600
# 92700
# 92800
# 92900
# 93000
# 93100
# 93200
# 93300
# 93400
# 93500
# 93600
# 93700
# 93800
# 93900
# 94000
# 94100
# 94200
# 94300
# 94400
# 94500
# 94600
# 94700
# 94800
# 94900
# 95000
# 95100
# 95200
# 95300
# 95400
# 95500
# 95600
# 95700
# 95800
# 95900
# 96000
# 96100
# 96200
# 96300
# 96400
# 96500
# 96600
# 96700
# 96800
# 96900
# 97000
# 97100
# 97200
# 97300
# 97400
# 97500
# 97600
# 97700
# 97800
# 97900
# 98000
# 98100
# 98200
# 98300
# 98400
# 98500
# 98600
# 98700
# 98800
# 98900
# 99000
# 99100
# 99200
# 99300
# 99400
# 99500
# 99600
# 99700
# 99800
# 99900

# %%
print('av. acceptance: ', out[3])

plt.plot(out[1])

plt.figure()
plt.plot(out[2])

print(np.mean(out[2]))

blocks = block_analysis(out[2], delta=10)

epsilons = blocks[3]
smooth_epsilons = blocks[4]

opt_epsilon = blocks[2]
print(opt_epsilon)

plt.figure()
plt.plot(epsilons, '-')
plt.plot(smooth_epsilons, '-')
plt.xscale('log')
# Out:
# av. acceptance:  0.81251
# 0.23718717397217343
# 0.014617369352987868

# %%
av_accept = out[3]
av_pop = [blocks[0], blocks[1], blocks[2]]

values[size] = [av_accept] + av_pop

# %%
weights_double = double(weights_orig)

# %%
proposal_full = {'fun': proposal, 'args': ([delta_w])}
energy_fun_full = {'fun': energy_fun, 'args': ([weights_double, if_Jeffreys, size])}  # here size is the initial one

out = run_Metropolis(weights_double, proposal=proposal_full, energy_function=energy_fun_full, n_steps=n_steps)
# Out:
# Warning: the quantities of interest are given by energy_function and not by quantity_function
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900
# 10000
# 10100
# 10200
# 10300
# 10400
# 10500
# 10600
# 10700
# 10800
# 10900
# 11000
# 11100
# 11200
# 11300
# 11400
# 11500
# 11600
# 11700
# 11800
# 11900
# 12000
# 12100
# 12200
# 12300
# 12400
# 12500
# 12600
# 12700
# 12800
# 12900
# 13000
# 13100
# 13200
# 13300
# 13400
# 13500
# 13600
# 13700
# 13800
# 13900
# 14000
# 14100
# 14200
# 14300
# 14400
# 14500
# 14600
# 14700
# 14800
# 14900
# 15000
# 15100
# 15200
# 15300
# 15400
# 15500
# 15600
# 15700
# 15800
# 15900
# 16000
# 16100
# 16200
# 16300
# 16400
# 16500
# 16600
# 16700
# 16800
# 16900
# 17000
# 17100
# 17200
# 17300
# 17400
# 17500
# 17600
# 17700
# 17800
# 17900
# 18000
# 18100
# 18200
# 18300
# 18400
# 18500
# 18600
# 18700
# 18800
# 18900
# 19000
# 19100
# 19200
# 19300
# 19400
# 19500
# 19600
# 19700
# 19800
# 19900
# 20000
# 20100
# 20200
# 20300
# 20400
# 20500
# 20600
# 20700
# 20800
# 20900
# 21000
# 21100
# 21200
# 21300
# 21400
# 21500
# 21600
# 21700
# 21800
# 21900
# 22000
# 22100
# 22200
# 22300
# 22400
# 22500
# 22600
# 22700
# 22800
# 22900
# 23000
# 23100
# 23200
# 23300
# 23400
# 23500
# 23600
# 23700
# 23800
# 23900
# 24000
# 24100
# 24200
# 24300
# 24400
# 24500
# 24600
# 24700
# 24800
# 24900
# 25000
# 25100
# 25200
# 25300
# 25400
# 25500
# 25600
# 25700
# 25800
# 25900
# 26000
# 26100
# 26200
# 26300
# 26400
# 26500
# 26600
# 26700
# 26800
# 26900
# 27000
# 27100
# 27200
# 27300
# 27400
# 27500
# 27600
# 27700
# 27800
# 27900
# 28000
# 28100
# 28200
# 28300
# 28400
# 28500
# 28600
# 28700
# 28800
# 28900
# 29000
# 29100
# 29200
# 29300
# 29400
# 29500
# 29600
# 29700
# 29800
# 29900
# 30000
# 30100
# 30200
# 30300
# 30400
# 30500
# 30600
# 30700
# 30800
# 30900
# 31000
# 31100
# 31200
# 31300
# 31400
# 31500
# 31600
# 31700
# 31800
# 31900
# 32000
# 32100
# 32200
# 32300
# 32400
# 32500
# 32600
# 32700
# 32800
# 32900
# 33000
# 33100
# 33200
# 33300
# 33400
# 33500
# 33600
# 33700
# 33800
# 33900
# 34000
# 34100
# 34200
# 34300
# 34400
# 34500
# 34600
# 34700
# 34800
# 34900
# 35000
# 35100
# 35200
# 35300
# 35400
# 35500
# 35600
# 35700
# 35800
# 35900
# 36000
# 36100
# 36200
# 36300
# 36400
# 36500
# 36600
# 36700
# 36800
# 36900
# 37000
# 37100
# 37200
# 37300
# 37400
# 37500
# 37600
# 37700
# 37800
# 37900
# 38000
# 38100
# 38200
# 38300
# 38400
# 38500
# 38600
# 38700
# 38800
# 38900
# 39000
# 39100
# 39200
# 39300
# 39400
# 39500
# 39600
# 39700
# 39800
# 39900
# 40000
# 40100
# 40200
# 40300
# 40400
# 40500
# 40600
# 40700
# 40800
# 40900
# 41000
# 41100
# 41200
# 41300
# 41400
# 41500
# 41600
# 41700
# 41800
# 41900
# 42000
# 42100
# 42200
# 42300
# 42400
# 42500
# 42600
# 42700
# 42800
# 42900
# 43000
# 43100
# 43200
# 43300
# 43400
# 43500
# 43600
# 43700
# 43800
# 43900
# 44000
# 44100
# 44200
# 44300
# 44400
# 44500
# 44600
# 44700
# 44800
# 44900
# 45000
# 45100
# 45200
# 45300
# 45400
# 45500
# 45600
# 45700
# 45800
# 45900
# 46000
# 46100
# 46200
# 46300
# 46400
# 46500
# 46600
# 46700
# 46800
# 46900
# 47000
# 47100
# 47200
# 47300
# 47400
# 47500
# 47600
# 47700
# 47800
# 47900
# 48000
# 48100
# 48200
# 48300
# 48400
# 48500
# 48600
# 48700
# 48800
# 48900
# 49000
# 49100
# 49200
# 49300
# 49400
# 49500
# 49600
# 49700
# 49800
# 49900
# 50000
# 50100
# 50200
# 50300
# 50400
# 50500
# 50600
# 50700
# 50800
# 50900
# 51000
# 51100
# 51200
# 51300
# 51400
# 51500
# 51600
# 51700
# 51800
# 51900
# 52000
# 52100
# 52200
# 52300
# 52400
# 52500
# 52600
# 52700
# 52800
# 52900
# 53000
# 53100
# 53200
# 53300
# 53400
# 53500
# 53600
# 53700
# 53800
# 53900
# 54000
# 54100
# 54200
# 54300
# 54400
# 54500
# 54600
# 54700
# 54800
# 54900
# 55000
# 55100
# 55200
# 55300
# 55400
# 55500
# 55600
# 55700
# 55800
# 55900
# 56000
# 56100
# 56200
# 56300
# 56400
# 56500
# 56600
# 56700
# 56800
# 56900
# 57000
# 57100
# 57200
# 57300
# 57400
# 57500
# 57600
# 57700
# 57800
# 57900
# 58000
# 58100
# 58200
# 58300
# 58400
# 58500
# 58600
# 58700
# 58800
# 58900
# 59000
# 59100
# 59200
# 59300
# 59400
# 59500
# 59600
# 59700
# 59800
# 59900
# 60000
# 60100
# 60200
# 60300
# 60400
# 60500
# 60600
# 60700
# 60800
# 60900
# 61000
# 61100
# 61200
# 61300
# 61400
# 61500
# 61600
# 61700
# 61800
# 61900
# 62000
# 62100
# 62200
# 62300
# 62400
# 62500
# 62600
# 62700
# 62800
# 62900
# 63000
# 63100
# 63200
# 63300
# 63400
# 63500
# 63600
# 63700
# 63800
# 63900
# 64000
# 64100
# 64200
# 64300
# 64400
# 64500
# 64600
# 64700
# 64800
# 64900
# 65000
# 65100
# 65200
# 65300
# 65400
# 65500
# 65600
# 65700
# 65800
# 65900
# 66000
# 66100
# 66200
# 66300
# 66400
# 66500
# 66600
# 66700
# 66800
# 66900
# 67000
# 67100
# 67200
# 67300
# 67400
# 67500
# 67600
# 67700
# 67800
# 67900
# 68000
# 68100
# 68200
# 68300
# 68400
# 68500
# 68600
# 68700
# 68800
# 68900
# 69000
# 69100
# 69200
# 69300
# 69400
# 69500
# 69600
# 69700
# 69800
# 69900
# 70000
# 70100
# 70200
# 70300
# 70400
# 70500
# 70600
# 70700
# 70800
# 70900
# 71000
# 71100
# 71200
# 71300
# 71400
# 71500
# 71600
# 71700
# 71800
# 71900
# 72000
# 72100
# 72200
# 72300
# 72400
# 72500
# 72600
# 72700
# 72800
# 72900
# 73000
# 73100
# 73200
# 73300
# 73400
# 73500
# 73600
# 73700
# 73800
# 73900
# 74000
# 74100
# 74200
# 74300
# 74400
# 74500
# 74600
# 74700
# 74800
# 74900
# 75000
# 75100
# 75200
# 75300
# 75400
# 75500
# 75600
# 75700
# 75800
# 75900
# 76000
# 76100
# 76200
# 76300
# 76400
# 76500
# 76600
# 76700
# 76800
# 76900
# 77000
# 77100
# 77200
# 77300
# 77400
# 77500
# 77600
# 77700
# 77800
# 77900
# 78000
# 78100
# 78200
# 78300
# 78400
# 78500
# 78600
# 78700
# 78800
# 78900
# 79000
# 79100
# 79200
# 79300
# 79400
# 79500
# 79600
# 79700
# 79800
# 79900
# 80000
# 80100
# 80200
# 80300
# 80400
# 80500
# 80600
# 80700
# 80800
# 80900
# 81000
# 81100
# 81200
# 81300
# 81400
# 81500
# 81600
# 81700
# 81800
# 81900
# 82000
# 82100
# 82200
# 82300
# 82400
# 82500
# 82600
# 82700
# 82800
# 82900
# 83000
# 83100
# 83200
# 83300
# 83400
# 83500
# 83600
# 83700
# 83800
# 83900
# 84000
# 84100
# 84200
# 84300
# 84400
# 84500
# 84600
# 84700
# 84800
# 84900
# 85000
# 85100
# 85200
# 85300
# 85400
# 85500
# 85600
# 85700
# 85800
# 85900
# 86000
# 86100
# 86200
# 86300
# 86400
# 86500
# 86600
# 86700
# 86800
# 86900
# 87000
# 87100
# 87200
# 87300
# 87400
# 87500
# 87600
# 87700
# 87800
# 87900
# 88000
# 88100
# 88200
# 88300
# 88400
# 88500
# 88600
# 88700
# 88800
# 88900
# 89000
# 89100
# 89200
# 89300
# 89400
# 89500
# 89600
# 89700
# 89800
# 89900
# 90000
# 90100
# 90200
# 90300
# 90400
# 90500
# 90600
# 90700
# 90800
# 90900
# 91000
# 91100
# 91200
# 91300
# 91400
# 91500
# 91600
# 91700
# 91800
# 91900
# 92000
# 92100
# 92200
# 92300
# 92400
# 92500
# 92600
# 92700
# 92800
# 92900
# 93000
# 93100
# 93200
# 93300
# 93400
# 93500
# 93600
# 93700
# 93800
# 93900
# 94000
# 94100
# 94200
# 94300
# 94400
# 94500
# 94600
# 94700
# 94800
# 94900
# 95000
# 95100
# 95200
# 95300
# 95400
# 95500
# 95600
# 95700
# 95800
# 95900
# 96000
# 96100
# 96200
# 96300
# 96400
# 96500
# 96600
# 96700
# 96800
# 96900
# 97000
# 97100
# 97200
# 97300
# 97400
# 97500
# 97600
# 97700
# 97800
# 97900
# 98000
# 98100
# 98200
# 98300
# 98400
# 98500
# 98600
# 98700
# 98800
# 98900
# 99000
# 99100
# 99200
# 99300
# 99400
# 99500
# 99600
# 99700
# 99800
# 99900

# %%
print('av. acceptance: ', out[3])

plt.plot(out[1])

plt.figure()
plt.plot(out[2])

print(np.mean(out[2]))

blocks = block_analysis(out[2], delta=10)

epsilons = blocks[3]
smooth_epsilons = blocks[4]

opt_epsilon = blocks[2]
print(opt_epsilon)

plt.figure()
plt.plot(epsilons, '-')
plt.plot(smooth_epsilons, '-')
plt.xscale('log')
plt.grid()
# Out:
# av. acceptance:  0.58302
# 0.2435377123016215
# 0.013991233975579541

# %%
av_accept = out[3]
av_pop = [blocks[0], blocks[1], blocks[2]]

values[size*2] = [av_accept] + av_pop

# %%
values
# Out:
# {4: [0.81251,
#   0.23718717397217343,
#   0.0006529610028237236,
#   0.014617369352987868],
#  8: [0.58302, 0.2435377123016215, 0.0005840756702740792, 0.013991233975579541]}

# %%
values
# Out:
# {4: [0.98837,
#   0.27129419169203484,
#   0.0005893140287874697,
#   0.012157490451257644],
#  8: [0.98355, 0.2507550769153702, 0.0004570420597290718, 0.008866495857542603]}

# %%
plt.errorbar(values.keys(), [values[i][1] for i in values.keys()], yerr=[values[i][3] for i in values.keys()])
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
import pandas

# %%
av_pop = [blocks[0], blocks[1], blocks[2]]

cols = ['av. accept', 'av. value', 'std', 'block error']
temp = pandas.DataFrame([av_accept] + av_pop, index=cols, columns=[0]).T
temp.to_csv('values.txt')

# %% [markdown]
# ### analysis

# %%
root_path = '../Results/sampling_frames/'
dir_list = os.listdir(root_path)

my_dfs = {}

for i, s in enumerate(dir_list):
    my_dfs[i] = pandas.read_csv(root_path + dir_list[i]).iloc[:, 1:]

my_df = pandas.concat(my_dfs)
my_df['name'] = dir_list
del my_dfs

my_df = my_df.sort_values(['n_steps', 'size', 'if_Jeffreys', 'n_times'], ignore_index=True)

my_df = my_df[my_df['size'] == 20]

my_df = my_df[my_df['n_steps'] == 10000000]

my_df
# Out:
#     size  seed  delta w     n_steps  n_times  if_Jeffreys  av. accept  \
# 60  20.0   1.0     0.01  10000000.0      1.0          0.0    0.930523
# 61  20.0   1.0     0.01  10000000.0      2.0          0.0    0.930572
# 62  20.0   1.0     0.01  10000000.0      3.0          0.0    0.930375
# 63  20.0   1.0     0.01  10000000.0      4.0          0.0    0.930221
# 64  20.0   1.0     0.01  10000000.0      5.0          0.0    0.930472
# 65  20.0   1.0     0.01  10000000.0      7.0          0.0    0.930450
# 66  20.0   1.0     0.01  10000000.0      8.0          0.0    0.930339
# 67  20.0   1.0     0.01  10000000.0      9.0          0.0    0.930312
# 68  20.0   1.0     0.01  10000000.0     10.0          0.0    0.930280
# 69  20.0   1.0     0.01  10000000.0     11.0          0.0    0.930441
# 70  20.0   1.0     0.01  10000000.0     12.0          0.0    0.930469
# 71  20.0   1.0     0.01  10000000.0     13.0          0.0    0.930490
# 72  20.0   1.0     0.01  10000000.0     14.0          0.0    0.930272
# 73  20.0   1.0     0.01  10000000.0     15.0          0.0    0.930484
# 74  20.0   1.0     0.01  10000000.0      1.0          1.0    0.213688
# 75  20.0   1.0     0.01  10000000.0      2.0          1.0    0.206681
# 76  20.0   1.0     0.01  10000000.0      3.0          1.0    0.209315
# 77  20.0   1.0     0.01  10000000.0      4.0          1.0    0.211822
# 78  20.0   1.0     0.01  10000000.0      5.0          1.0    0.207795
# 79  20.0   1.0     0.01  10000000.0      6.0          1.0    0.214217
# 80  20.0   1.0     0.01  10000000.0      7.0          1.0    0.213291
# 81  20.0   1.0     0.01  10000000.0      9.0          1.0    0.209598
# 82  20.0   1.0     0.01  10000000.0     10.0          1.0    0.209738
# 83  20.0   1.0     0.01  10000000.0     11.0          1.0    0.208710
# 84  20.0   1.0     0.01  10000000.0     12.0          1.0    0.212835
# 85  20.0   1.0     0.01  10000000.0     13.0          1.0    0.214009
# 86  20.0   1.0     0.01  10000000.0     14.0          1.0    0.212556
# 87  20.0   1.0     0.01  10000000.0     15.0          1.0    0.212113
#
#     av. value       std  block error                                   name
# 60   0.051315  0.000015     0.000206  values_2024_12_17_11_17_44_661400.txt
# 61   0.051526  0.000015     0.000209  values_2024_12_17_11_12_45_922748.txt
# 62   0.051321  0.000015     0.000205  values_2024_12_17_11_21_24_221950.txt
# 63   0.051335  0.000015     0.000212  values_2024_12_17_11_20_27_485043.txt
# 64   0.051439  0.000015     0.000204  values_2024_12_17_11_21_24_350747.txt
# 65   0.051304  0.000015     0.000201  values_2024_12_17_11_16_56_368523.txt
# 66   0.051373  0.000015     0.000206  values_2024_12_17_11_13_01_327572.txt
# 67   0.051169  0.000015     0.000209  values_2024_12_17_11_19_36_573296.txt
# 68   0.051329  0.000015     0.000205  values_2024_12_17_11_24_39_851503.txt
# 69   0.051349  0.000015     0.000207  values_2024_12_17_11_19_23_065697.txt
# 70   0.050905  0.000015     0.000202  values_2024_12_17_11_18_49_894278.txt
# 71   0.051515  0.000015     0.000209  values_2024_12_17_11_17_00_133925.txt
# 72   0.051578  0.000015     0.000207  values_2024_12_17_11_24_55_029913.txt
# 73   0.051280  0.000015     0.000204  values_2024_12_17_11_27_42_198547.txt
# 74   0.051029  0.000020     0.000683  values_2024_12_17_11_15_13_934375.txt
# 75   0.050218  0.000021     0.000714  values_2024_12_17_11_14_08_270174.txt
# 76   0.055272  0.000021     0.000729  values_2024_12_17_11_19_20_895631.txt
# 77   0.052817  0.000021     0.000692  values_2024_12_17_12_24_43_530077.txt
# 78   0.052020  0.000021     0.000718  values_2024_12_17_11_15_35_269106.txt
# 79   0.052253  0.000021     0.000720  values_2024_12_17_11_23_10_117074.txt
# 80   0.054360  0.000021     0.000735  values_2024_12_17_11_14_57_310635.txt
# 81   0.053178  0.000021     0.000680  values_2024_12_17_11_30_08_094035.txt
# 82   0.052058  0.000021     0.000728  values_2024_12_17_11_20_26_924870.txt
# 83   0.052310  0.000020     0.000679  values_2024_12_17_11_18_03_656864.txt
# 84   0.051489  0.000020     0.000733  values_2024_12_17_11_19_23_603482.txt
# 85   0.051046  0.000020     0.000659  values_2024_12_17_11_34_19_313246.txt
# 86   0.052613  0.000021     0.000728  values_2024_12_17_11_41_25_759573.txt
# 87   0.051233  0.000020     0.000670  values_2024_12_17_11_25_34_662851.txt

# %%
upto = 15

x = np.arange(upto)
plt.errorbar(x, my_df.iloc[:upto]['av. value'], my_df.iloc[:upto]['block error'], label='without Jeffreys')

x = list(set(x)- set([8]))
plt.errorbar(x, my_df.iloc[(upto - 1):(2*upto)]['av. value'], my_df.iloc[(upto - 1):(2*upto)]['block error'], label='with Jeffreys')

plt.legend()
plt.grid()
