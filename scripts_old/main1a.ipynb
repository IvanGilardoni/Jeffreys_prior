# %% [markdown]
# # Quadratic well

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
from basic_functions_bayesian import local_density, run_Metropolis, compute_single, compute

# %%
alpha = 1

# %% [markdown]
# ### 1 dimension

# %%
mean = 0
std = np.sqrt(0.8)
how_many = 10000

x = np.random.normal(mean, std, size=how_many)

p0 = np.ones(len(x.T))
p0 = p0/np.sum(p0)

# %% [markdown]
# #### a. soft restraint on the elastic strength / variance

# %% [markdown]
# - what happens if the restraint is on the variance rather than on the elastic strength?
#
# \begin{equation*}
#
# |d\langle x^2\rangle| = \frac{1}{k^2} |dk|
#
# \end{equation*}
#
# therefore if we sample the hyper-ensemble by using $d\langle x^2\rangle$ or $dk$ (i.e., same n. of ensembles for the same variation of the av. value of $x^2$ or $1/x^2$) we get different results, instead with the Jeffreys prior there is not this ambiguity!
#
# However, in this case the resulting optimal ensemble parametrized by $\lambda$ is a different set of ensembles in the two cases: $e^{-\lambda x^2}$ or $e^{-\lambda' \, 1/x^2}$
#
# you can have the same functional form in the case of force-field fitting

# %%
g = (x - mean)**2

gexp = 0.1
sigma = 0.05

# %%
lambdas = 0.1

# %%
p0 = p0/np.sum(p0)

P = p0
"""`numpy.ndarray` reporting the new (reweighted) probability distribution."""

if len(g.shape) == 1: P *= np.exp(-lambdas*g)  # np.exp(-np.dot(lambda_i, g[np.newaxis, 0]))
else: P *= np.exp(-np.dot(lambdas, g))

Z = np.sum(P)
"""`float` reporting the partition function `Z lambda`."""
P = P/Z

# %%
lambdas = 0.1

out = compute_single(lambdas, p0, np.array([g]), gexp, sigma, alpha)
# out = compute_single(np.array([lambdas]), p0, np.array([g]), gexp, sigma, alpha)

vars(out)
# Out:
# {'P': array([1.14534553e-04, 9.27993658e-05, 1.07481132e-04, ...,
#         1.11827793e-04, 9.90114228e-05, 9.92944230e-05]),
#  'Z': 0.9374291938607313,
#  'av_g': array([0.60665464]),
#  'av_g2': array([1.09386505]),
#  'var_g': 0.7258352003352876,
#  'std_g': 0.8519596236531914,
#  'chi2': array([102.67956902]),
#  'Srel': -0.003948586704643778,
#  'lossf': 51.343733096493416,
#  'gamma': array([-0.05460155]),
#  'jeffreys': 0.8519596236531923,
#  'cov': array([[0.7258352]]),
#  'dirichlet': 0.007076033163367456,
#  'avg_density': 0.7258352003352891}

# %%
lambdas = np.arange(-5, 70, 0.01)

results = compute(lambdas, p0, g, gexp, sigma, alpha)

results.keys()
# Out:
# dict_keys(['P', 'Z', 'av_g', 'av_g2', 'var_g', 'std_g', 'chi2', 'Srel', 'lossf', 'gamma', 'jeffreys', 'cov', 'dirichlet', 'avg_density'])

# %%
plt.plot(lambdas, results['av_g'], '-', label=r'$\langle g \rangle$')
plt.plot([lambdas[0], lambdas[-1]], [gexp, gexp], '--', label='g_exp')
#plt.yscale('log')
plt.xlabel('lambda')
plt.legend()
plt.grid()

# %%
plt.plot(lambdas, 1/2*results['chi2'], label='1/2 chi2')
plt.plot(lambdas, -results['Srel'], label='D KL')
plt.plot(lambdas, results['lossf'], label='loss')
plt.yscale('log')
plt.legend()
plt.grid()

# %%
# plt.plot(lambdas, 1/2*results['chi2'], label='1/2 chi2')
# plt.plot(lambdas, -results['Srel'], label='D KL')
plt.plot(lambdas, results['lossf'], label='loss')
# plt.plot(lambdas, -np.log(results['std_g']), label='jeffreys')
plt.plot(lambdas, results['lossf'] - np.log(results['std_g']), label='jeffreys loss')
# plt.plot(lambdas, -np.log(results['dirichlet']), label='dirichlet')
plt.plot(lambdas, results['lossf'] - np.log(results['dirichlet']), label='dirichlet loss')
# plt.plot(lambdas, -np.log(results['avg_density']), label='av.g density')
plt.plot(lambdas, results['lossf'] - np.log(results['avg_density']), label='av.g loss')

plt.grid()
plt.legend()
plt.yscale('log')

# %%
for s in ['lossf', 'jeffreys']:
    plt.plot(np.ediff1d(np.log(results[s])), label=s)
    
plt.yscale('symlog')
plt.legend()
plt.grid()

# %%
plt.plot(lambdas, -np.log(results['std_g']))
plt.yscale('log')
plt.grid()

# %%
normalize = lambda x: x/np.sum(x)

plt.plot(lambdas, normalize(results['std_g']), '-', label=r'$\sigma(\lambda)$', c='k')
#plt.plot(lambdas,-np.log(dirichlets),'-',label='equiv. for Dirichlet')

plt.plot(lambdas[1:], normalize(np.abs(np.ediff1d(results['av_g'])/np.ediff1d(lambdas))), '.', label=r'$d\langle g\rangle/d\lambda$')
plt.plot(lambdas, normalize(results['std_g']**2), '-', label=r'$\sigma(\lambda)^2$')

plt.plot(lambdas, normalize(results['dirichlet']), '-', label='dirichlet')

plt.xlabel(r'$\lambda$')
plt.grid()
plt.legend()
plt.xlim([-5, 5])
plt.title('ensemble number density (normalized)')
plt.show()

# %% [markdown]
# #### b. soft restraint on the equilibrium position

# %%
g = x

gexp = 0.3
sigma = 0.25

# %%
lambdas = np.arange(-100, 100, 0.1)

results = compute(lambdas, p0, g, gexp, sigma, alpha)

results.keys()
# Out:
# dict_keys(['P', 'Z', 'av_g', 'av_g2', 'var_g', 'std_g', 'chi2', 'Srel', 'lossf', 'gamma', 'jeffreys', 'cov', 'dirichlet', 'avg_density'])

# %%
plt.plot(lambdas, 1/2*results['chi2'], label='1/2 chi2')
plt.plot(lambdas, -results['Srel'], label='D KL')
plt.plot(lambdas, results['lossf'], label='loss')
plt.plot(lambdas, -np.log(results['std_g']), label='jeffreys')
plt.plot(lambdas, results['lossf'] - np.log(results['std_g']), label='jeffreys loss')
plt.plot(lambdas, -np.log(results['dirichlet']), label='dirichlet')
plt.plot(lambdas, results['lossf'] - np.log(results['dirichlet']), label='dirichlet loss')

plt.grid()
plt.legend()
# plt.yscale('log')

# %%
normalize = lambda x: x/np.sum(x)

plt.plot(lambdas, normalize(results['std_g']), '-', label=r'$\sigma(\lambda)$', c='k')
#plt.plot(lambdas,-np.log(dirichlets),'-',label='equiv. for Dirichlet')

plt.plot(lambdas[1:], normalize(np.abs(np.ediff1d(results['av_g'])/np.ediff1d(lambdas))), '.', label=r'$d\langle g\rangle/d\lambda$')
plt.plot(lambdas, normalize(results['std_g']**2), '-', label=r'$\sigma(\lambda)^2$')

plt.xlabel(r'$\lambda$')
plt.grid()
plt.legend()
# plt.xlim([-30, 30])
plt.title('ensemble number density (normalized)')
plt.show()

# %% [markdown]
# ### 2 dimensions

# %%
mean = np.array([0, 0])
cov = 0.1*np.identity(2)
how_many = 500

x = np.random.multivariate_normal(mean, cov, size=how_many)

p0 = np.ones(len(x))
p0 = p0/np.sum(p0)

# %%
g = ((x - mean)**2).T

gexp = [0.4, 0.2]
sigma = [0.15, 0.1]

# %%
out = compute_single(np.array([0.1, 0.1]), p0, g, gexp, sigma, alpha)

vars(out)
# Out:
# {'P': array([0.00200684, 0.00200194, 0.00185927, 0.00201627, 0.00202246,
#         0.00201521, 0.00202996, 0.00203545, 0.00200208, 0.00202404,
#         0.0019919 , 0.00191553, 0.00196287, 0.00197843, 0.00196368,
#         0.00199176, 0.00203088, 0.00201769, 0.00202206, 0.00194863,
#         0.00197467, 0.00201046, 0.0020017 , 0.0019655 , 0.00203083,
#         0.00203554, 0.00201921, 0.00198758, 0.00203843, 0.0019767 ,
#         0.00186253, 0.00203033, 0.00203763, 0.00188491, 0.00195077,
#         0.00203648, 0.00203168, 0.00201023, 0.00197674, 0.00201568,
#         0.00175702, 0.00201494, 0.00201727, 0.0020364 , 0.002011  ,
#         0.00202615, 0.00203929, 0.00201324, 0.00199748, 0.0019756 ,
#         0.00194538, 0.00201072, 0.00203846, 0.00201298, 0.0020274 ,
#         0.00201207, 0.00198429, 0.00202937, 0.00201715, 0.00203163,
#         0.00198662, 0.00200687, 0.00196727, 0.0019543 , 0.00202386,
#         0.00193595, 0.00203029, 0.002035  , 0.00200514, 0.00203562,
#         0.00203355, 0.00198106, 0.00203007, 0.00199965, 0.00198712,
#         0.0019915 , 0.00196702, 0.00197558, 0.0020315 , 0.00200493,
#         0.00203824, 0.00183024, 0.00202879, 0.0019799 , 0.0020155 ,
#         0.00198926, 0.00196954, 0.00202275, 0.0020273 , 0.00203559,
#         0.00200274, 0.00200782, 0.00203324, 0.00198959, 0.00190198,
#         0.00201983, 0.00200399, 0.00199921, 0.00201484, 0.00203631,
#         0.00201667, 0.00190588, 0.00203065, 0.00203397, 0.00202771,
#         0.00203121, 0.00203906, 0.00200517, 0.00198474, 0.00202484,
#         0.00201716, 0.00197569, 0.00203964, 0.00200662, 0.00203648,
#         0.0020328 , 0.00203168, 0.00203415, 0.00193368, 0.00197022,
#         0.00199706, 0.00192133, 0.00201455, 0.002012  , 0.00201426,
#         0.00200299, 0.00201808, 0.00203238, 0.00203262, 0.00193561,
#         0.00192856, 0.00202495, 0.00200908, 0.00201673, 0.00197955,
#         0.0020004 , 0.00203798, 0.00197721, 0.00195806, 0.00190171,
#         0.00202239, 0.00201152, 0.00202111, 0.00200353, 0.00201871,
#         0.0019434 , 0.00195399, 0.00203503, 0.00198847, 0.00200817,
#         0.00198405, 0.00202714, 0.00202131, 0.00199774, 0.00197652,
#         0.00196469, 0.0019057 , 0.00191666, 0.00203264, 0.00203429,
#         0.00201715, 0.00201557, 0.00201055, 0.0019875 , 0.00202897,
#         0.00203398, 0.00203722, 0.00192132, 0.00201816, 0.00203168,
#         0.002022  , 0.00202366, 0.00196544, 0.00196766, 0.00203104,
#         0.00195524, 0.00200843, 0.00202665, 0.00203721, 0.00201729,
#         0.00199265, 0.00200638, 0.0020357 , 0.00199844, 0.00201563,
#         0.00200737, 0.00179991, 0.00203806, 0.00198111, 0.00203764,
#         0.00196828, 0.00198477, 0.00203672, 0.00202311, 0.00203118,
#         0.00202962, 0.00201896, 0.00203856, 0.0019891 , 0.00202146,
#         0.00203689, 0.00197221, 0.00201923, 0.00202571, 0.00203632,
#         0.00195275, 0.00201983, 0.00203864, 0.00200879, 0.00202245,
#         0.00201017, 0.00202899, 0.00193531, 0.00202836, 0.00200127,
#         0.00196424, 0.00191597, 0.00201976, 0.00203762, 0.00203894,
#         0.00202231, 0.0020238 , 0.00202201, 0.00203889, 0.00202926,
#         0.00197591, 0.00201847, 0.00198411, 0.00199754, 0.00202576,
#         0.00200184, 0.0020124 , 0.0020066 , 0.0020183 , 0.00203742,
#         0.00200145, 0.00201488, 0.00202358, 0.00202352, 0.00203815,
#         0.00202709, 0.00202793, 0.00203253, 0.00199493, 0.00201783,
#         0.00199847, 0.00200233, 0.00200675, 0.00200201, 0.00202691,
#         0.00203638, 0.00195328, 0.00203777, 0.00203671, 0.00202088,
#         0.00201066, 0.00202348, 0.00198916, 0.00197043, 0.00201831,
#         0.00199382, 0.00199774, 0.00197536, 0.00198705, 0.00200059,
#         0.00198477, 0.00203207, 0.00203043, 0.00196472, 0.00203768,
#         0.00199789, 0.00195671, 0.00203337, 0.0020022 , 0.00202966,
#         0.00201154, 0.00200313, 0.0019833 , 0.0019995 , 0.00203756,
#         0.0018984 , 0.00202419, 0.00202085, 0.00199787, 0.00202489,
#         0.00201666, 0.00189957, 0.00194236, 0.00202177, 0.00201798,
#         0.00201552, 0.00199899, 0.00198083, 0.00190242, 0.00198746,
#         0.0019245 , 0.00196496, 0.0020254 , 0.00203039, 0.00200947,
#         0.00201556, 0.0020179 , 0.00186751, 0.00187927, 0.00203318,
#         0.00203237, 0.00203688, 0.00196978, 0.00199894, 0.00200166,
#         0.00196648, 0.00202413, 0.00198358, 0.00203643, 0.00192748,
#         0.00198304, 0.00193329, 0.00196541, 0.00200763, 0.00203626,
#         0.00201523, 0.00199594, 0.00193897, 0.00196938, 0.00202403,
#         0.00200223, 0.0019927 , 0.0020223 , 0.00199287, 0.00197447,
#         0.00198061, 0.00201285, 0.0020315 , 0.00202269, 0.00201347,
#         0.0020223 , 0.00200223, 0.0020263 , 0.00203707, 0.00201959,
#         0.00200289, 0.00200701, 0.00203712, 0.00203214, 0.00195076,
#         0.00198766, 0.0020209 , 0.00202085, 0.00202411, 0.00202905,
#         0.00203703, 0.00200842, 0.00197702, 0.00203112, 0.00190141,
#         0.00201333, 0.00202604, 0.00203485, 0.00193409, 0.00201927,
#         0.00198756, 0.0020044 , 0.00201525, 0.00202819, 0.00201111,
#         0.00192389, 0.00202682, 0.00201971, 0.00197118, 0.00189184,
#         0.00203885, 0.00203937, 0.00197786, 0.002024  , 0.00201244,
#         0.0020384 , 0.0020295 , 0.00201886, 0.00201036, 0.00203931,
#         0.00199978, 0.00198062, 0.00196789, 0.00202293, 0.00201755,
#         0.00201616, 0.0019681 , 0.00203269, 0.00198846, 0.00195471,
#         0.00202407, 0.00202139, 0.00202407, 0.0020319 , 0.00197305,
#         0.00197235, 0.0020152 , 0.00199024, 0.00201589, 0.00203934,
#         0.00197539, 0.0020249 , 0.0019282 , 0.00203852, 0.00194395,
#         0.00202949, 0.0020289 , 0.00192741, 0.00191275, 0.00193612,
#         0.00202054, 0.00200517, 0.00196882, 0.00202242, 0.00201412,
#         0.00202875, 0.00203856, 0.00202378, 0.0020334 , 0.0020222 ,
#         0.00201521, 0.00203554, 0.00198913, 0.0020308 , 0.00202208,
#         0.00196481, 0.00203386, 0.00184174, 0.0019648 , 0.00202452,
#         0.00195599, 0.00197122, 0.00203521, 0.00200602, 0.00202076,
#         0.00203547, 0.0020348 , 0.00195328, 0.00203941, 0.00202056,
#         0.00193744, 0.00187315, 0.00197074, 0.00199686, 0.00200878,
#         0.0020304 , 0.00201607, 0.00200405, 0.00201108, 0.00199582,
#         0.00203314, 0.00186016, 0.00201364, 0.00197104, 0.00201355,
#         0.00189045, 0.00197537, 0.00200304, 0.00203716, 0.00191882,
#         0.00199527, 0.00202536, 0.0019323 , 0.00199622, 0.0020265 ,
#         0.00198858, 0.00203443, 0.0019351 , 0.00203935, 0.00202615,
#         0.00202232, 0.00201094, 0.00201602, 0.00202735, 0.00196033,
#         0.0020259 , 0.00199455, 0.00203747, 0.00201411, 0.00199772,
#         0.00203661, 0.00201775, 0.00202826, 0.00203725, 0.00203149,
#         0.00196352, 0.00197236, 0.00193128, 0.00202731, 0.00202975,
#         0.00203473, 0.00203673, 0.00202218, 0.0020064 , 0.00200693,
#         0.00203165, 0.00194689, 0.00202551, 0.00202375, 0.00198995]),
#  'Z': 0.980514259002434,
#  'av_g': array([0.09467975, 0.10004526]),
#  'av_g2': array([0.02657401, 0.0316293 ]),
#  'var_g': array([0.01760975, 0.02162025]),
#  'std_g': array([0.13270174, 0.14703826]),
#  'chi2': array([4.1431313 , 0.99909509]),
#  'Srel': -0.00020559014980055246,
#  'lossf': 2.5713187843713756,
#  'gamma': 0.04063440913132022,
#  'jeffreys': 0.01950113794834926,
#  'cov': array([[0.01760975, 0.00065791],
#         [0.00065791, 0.02162025]]),
#  'dirichlet': 3.74574911085198e-05,
#  'avg_density': 0.00038029438128054754}

# %%
lambdas = np.arange(-25, 25, 0.1)

results = compute((lambdas, lambdas), p0, g, gexp, sigma, alpha)
# Out:
# /u/i/igilardo/5_Jeffreys/Jeffreys_prior/basic_functions_bayesian.py:337: RuntimeWarning: invalid value encountered in sqrt
#   density = np.sqrt(np.linalg.det(metric))

# %%
matplotlib.rcParams['pcolor.shading'] = 'auto'

flatten = lambda results, s: [[results[l1][l2][s] for l1 in results.keys()] for l2 in results.keys()]

loss = flatten(results, 'lossf')
jeff = flatten(results, 'jeffreys')
avg = np.array(flatten(results,'av_g'))

# plt.imshow(lambdas, lambdas, loss, 'jet')
# plt.pcolormesh(lambdas, lambdas, loss, cmap='jet')
plt.pcolormesh(lambdas, lambdas, -np.log(jeff), cmap='jet')
plt.title('jeffreys')
plt.colorbar()

plt.figure()
plt.title('loss')
plt.pcolormesh(lambdas, lambdas, loss, cmap='jet')
plt.colorbar()

plt.figure()
plt.title('loss - jeff')
plt.pcolormesh(lambdas, lambdas, loss - np.log(jeff), cmap='jet')
plt.colorbar()

plt.figure()
plt.title('avg0 + avg1')
plt.pcolormesh(lambdas, lambdas, avg[:, :, 0] + avg[:, :, 1], cmap='jet')
plt.colorbar()

plt.figure()
plt.title('avg0')
plt.pcolormesh(lambdas, lambdas, avg[:, :, 0], cmap='jet')
plt.colorbar()

plt.figure()
plt.title('avg1')
plt.pcolormesh(lambdas, lambdas, avg[:, :, 1], cmap='jet')
plt.colorbar()
plt.show()

# %%
lambdas0 = np.zeros(2)

def proposal(x0, dx=0.01):
    x_new = x0 + dx*np.random.normal(size=len(x0))
    return x_new

proposal_full = {'fun': proposal, 'args': ([0.5])}

def energy_fun(lambdas, if_Jeffreys):
    
    out = compute_single(lambdas, p0, g, gexp, sigma, alpha)
    
    energy = out.lossf

    av_g = out.av_g

    if if_Jeffreys:
        measure = local_density(g.T, out.P)[0]
        energy -= np.log(measure)
    
    return energy, av_g

# %%
energy_function = {'fun': energy_fun, 'args': ([True])}
out_J = run_Metropolis(lambdas0, proposal_full, energy_function, n_steps=10000)

energy_function = {'fun': energy_fun, 'args': ([False])}
out_noJ = run_Metropolis(lambdas0, proposal_full, energy_function, n_steps=10000)
# Out:
# Warning: the quantities of interest are given by energy_function
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900
# Warning: the quantities of interest are given by energy_function
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900

# %%
print('acceptance: ', out_J[2], out_noJ[2])
# Out:
# acceptance:  0.8312 0.8992

# %%
plt.plot(out_J[0], label='Jeffreys')
plt.plot(out_noJ[0], label='no Jeffreys')
plt.legend()

# %%
plt.plot(out_J[1], label='Jeffreys')
plt.plot(out_noJ[1], label='no Jeffreys')
plt.title('energy')
plt.legend()

# %%
plt.plot(out_J[3][:, 0], label='Jeffreys')
plt.plot(out_noJ[3][:, 0], label='no Jeffreys')
plt.legend()

plt.figure()
plt.plot(out_J[3][:, 1], label='Jeffreys')
plt.plot(out_noJ[3][:, 1], label='no Jeffreys')
plt.legend()

# %%
av_J = np.mean(out_J[3], axis=0)
av_noJ = np.mean(out_noJ[3], axis=0)

print(av_J, av_noJ)

# here you should use block analysis
std_J = np.std(out_J[3], axis=0)/np.sqrt(len(out_J[3]))
std_noJ = np.std(out_noJ[3], axis=0)/np.sqrt(len(out_noJ[3]))

print(std_J, std_noJ)

order_par = (np.sum((av_J - av_noJ)**2/(std_J**2 + std_noJ**2)))
print(order_par)
# Out:
# [0.29959726 0.17350614] [0.26821156 0.09983293]
# [0.00139371 0.00079875] [0.00147027 0.00077433]
# 4625.725239091079
